# %%
import torch
from src.CNN import CNNActionValue

# 모델 정의
state_dim = (4, 84, 84) 
action_dim = 5  

# 모델 생성
model = CNNActionValue(state_dim[0], action_dim)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('/home/seohyunk/seani/DQN-Car-Racing-master/dqn_cnn_2.pt'))

# 모델 가중치 출력
for name, param in model.named_parameters():
    print(name, param.data)
# Out:
# conv1.weight tensor([[[[-0.0536,  0.0013,  0.0208,  ..., -0.0374, -0.0338,  0.0326],
#           [ 0.0537,  0.0588, -0.0085,  ..., -0.0108,  0.0233, -0.0512],
#           [-0.0429, -0.0027,  0.0502,  ..., -0.0630, -0.0117, -0.0062],
#           ...,
#           [ 0.0222, -0.0454,  0.0570,  ...,  0.0208, -0.0132,  0.0384],
#           [ 0.0029,  0.0248,  0.0382,  ..., -0.0636, -0.0089, -0.0026],
#           [-0.0398, -0.0043,  0.0079,  ...,  0.0237, -0.0511,  0.0091]],
#
#          [[-0.0303, -0.0627, -0.0189,  ..., -0.0632, -0.0490, -0.0096],
#           [ 0.0203,  0.0199, -0.0407,  ..., -0.0227,  0.0546, -0.0173],
#           [ 0.0413, -0.0284, -0.0203,  ..., -0.0292,  0.0209, -0.0054],
#           ...,
#           [ 0.0545, -0.0048,  0.0299,  ...,  0.0035,  0.0370,  0.0439],
#           [-0.0397, -0.0410,  0.0016,  ...,  0.0163,  0.0358,  0.0162],
#           [-0.0612,  0.0275, -0.0613,  ...,  0.0460,  0.0431,  0.0301]],
#
# ...
